# %% [markdown]
# # IMPORTIG PACKAGES

# %%
#Import all relevant libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.frequent_patterns import apriori

# %% [markdown]
# # IMPORTING THE DATASET

# %%
df=pd.read_csv("basket_analysis.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Apple  Bread  Butter  Cheese   Corn   Dill   Eggs  Ice cream  \
# 0           0  False   True   False   False   True   True  False       True
# 1           1  False  False   False   False  False  False  False      False
# 2           2   True  False    True   False  False   True  False       True
# 3           3  False  False    True    True  False   True  False      False
# 4           4   True   True   False   False  False  False  False      False
#
#    Kidney Beans   Milk  Nutmeg  Onion  Sugar  Unicorn  Yogurt  chocolate
# 0         False  False   False  False   True    False    True       True
# 1         False   True   False  False  False    False   False      False
# 2         False   True   False  False  False    False    True       True
# 3         False   True    True   True  False    False   False      False
# 4         False  False   False  False  False    False   False      False

# %%
df.shape
# Out:
# (999, 17)

# %% [markdown]
# # CREATING A FREQUENT SET

# %%
df.drop(df.columns[0],axis=1,inplace=True)

# %%
frequent_itemsets = apriori(df,
                            min_support = .006,
                            max_len = 3,
                            use_colnames = True)

# %%
rules = association_rules(frequent_itemsets,
                            metric = 'support',
                            min_threshold=0.1)

# %% [markdown]
# # adding antecedent(foreruning) & consequent(foregoing)

# %%
filtered_rules = rules[(rules['antecedent support'] > 0.02)&
                        (rules['consequent support'] >0.01) &
                        (rules['confidence'] > 0.2) &
                        (rules['lift'] > 1.0)]

# %%
filtered_rules.sort_values('confidence',ascending=False)
# Out:
#                    antecedents           consequents  antecedent support  \
# 402            (Unicorn, Dill)           (chocolate)            0.168168
# 390               (Milk, Dill)           (chocolate)            0.190190
# 325             (Dill, Cheese)               (Onion)            0.177177
# 392          (Dill, chocolate)                (Milk)            0.199199
# 258  (Ice cream, Kidney Beans)              (Butter)            0.196196
# ..                         ...                   ...                 ...
# 286                   (Butter)  (Ice cream, Unicorn)            0.420420
# 244                   (Butter)        (Sugar, Apple)            0.420420
# 322                   (Yogurt)      (Butter, Nutmeg)            0.420420
# 321                   (Butter)      (Nutmeg, Yogurt)            0.420420
# 377                (chocolate)  (Corn, Kidney Beans)            0.421421
#
#      consequent support   support  confidence      lift  leverage  conviction
# 402            0.421421  0.101101    0.601190  1.426578  0.030231    1.450764
# 390            0.421421  0.114114    0.600000  1.423753  0.033964    1.446446
# 325            0.403403  0.102102    0.576271  1.428523  0.030628    1.407968
# 392            0.405405  0.114114    0.572864  1.413065  0.033358    1.392051
# 258            0.420420  0.110110    0.561224  1.334913  0.027625    1.320902
# ..                  ...       ...         ...       ...       ...         ...
# 286            0.185185  0.100100    0.238095  1.285714  0.022244    1.069444
# 244            0.182182  0.100100    0.238095  1.306907  0.023507    1.073386
# 322            0.198198  0.100100    0.238095  1.201299  0.016774    1.052365
# 321            0.192192  0.100100    0.238095  1.238839  0.019299    1.060248
# 377            0.195195  0.100100    0.237530  1.216883  0.017841    1.055523
#
# [436 rows x 9 columns]

# %%
sns.scatterplot(x = "support", y = "confidence", data = filtered_rules)
plt.show()

# %%
filtered_rules = rules[(rules['antecedent support'] > 0.02)&
                        (rules['consequent support'] >0.01) &
                        (rules['confidence'] > 0.45) &
                        (rules['lift'] > 1.0)]

# %%
sns.scatterplot(x = "support", y = "confidence", size= 'leverage',data = filtered_rules)
plt.legend(bbox_to_anchor= (1.02, 1), loc='upper left',)
plt.show()

# %%
filtered_rules = rules[(rules['antecedent support'] > 0.02)&
                        (rules['consequent support'] >0.01) &
                        (rules['confidence'] > 0.45) &
                        (rules['lift'] > 1.0)&
                        (rules['support']>0.195)]

# %%
filtered_rules
# Out:
#         antecedents     consequents  antecedent support  consequent support  \
# 66      (Ice cream)        (Butter)            0.410410            0.420420
# 67         (Butter)     (Ice cream)            0.420420            0.410410
# 68   (Kidney Beans)        (Butter)            0.408408            0.420420
# 69         (Butter)  (Kidney Beans)            0.420420            0.408408
# 70           (Milk)        (Butter)            0.405405            0.420420
# 71         (Butter)          (Milk)            0.420420            0.405405
# 72         (Butter)        (Nutmeg)            0.420420            0.401401
# 73         (Nutmeg)        (Butter)            0.401401            0.420420
# 74         (Butter)         (Onion)            0.420420            0.403403
# 75          (Onion)        (Butter)            0.403403            0.420420
# 76          (Sugar)        (Butter)            0.409409            0.420420
# 77         (Butter)         (Sugar)            0.420420            0.409409
# 82         (Butter)     (chocolate)            0.420420            0.421421
# 83      (chocolate)        (Butter)            0.421421            0.420420
# 92   (Kidney Beans)        (Cheese)            0.408408            0.404404
# 93         (Cheese)  (Kidney Beans)            0.404404            0.408408
# 114          (Corn)  (Kidney Beans)            0.407407            0.408408
# 115  (Kidney Beans)          (Corn)            0.408408            0.407407
# 148          (Dill)     (chocolate)            0.398398            0.421421
# 149     (chocolate)          (Dill)            0.421421            0.398398
# 168     (Ice cream)  (Kidney Beans)            0.410410            0.408408
# 169  (Kidney Beans)     (Ice cream)            0.408408            0.410410
# 176         (Sugar)     (Ice cream)            0.409409            0.410410
# 177     (Ice cream)         (Sugar)            0.410410            0.409409
# 182     (Ice cream)     (chocolate)            0.410410            0.421421
# 183     (chocolate)     (Ice cream)            0.421421            0.410410
# 184          (Milk)  (Kidney Beans)            0.405405            0.408408
# 185  (Kidney Beans)          (Milk)            0.408408            0.405405
# 208          (Milk)     (chocolate)            0.405405            0.421421
# 209     (chocolate)          (Milk)            0.421421            0.405405
# 210         (Onion)        (Nutmeg)            0.403403            0.401401
# 211        (Nutmeg)         (Onion)            0.401401            0.403403
# 226     (chocolate)         (Onion)            0.421421            0.403403
# 227         (Onion)     (chocolate)            0.403403            0.421421
# 238     (chocolate)        (Yogurt)            0.421421            0.420420
# 239        (Yogurt)     (chocolate)            0.420420            0.421421
#
#       support  confidence      lift  leverage  conviction
# 66   0.207207    0.504878  1.200889  0.034662    1.170579
# 67   0.207207    0.492857  1.200889  0.034662    1.162571
# 68   0.202202    0.495098  1.177626  0.030499    1.147905
# 69   0.202202    0.480952  1.177626  0.030499    1.139764
# 70   0.198198    0.488889  1.162857  0.027757    1.133960
# 71   0.198198    0.471429  1.162857  0.027757    1.124909
# 72   0.198198    0.471429  1.174457  0.029441    1.132484
# 73   0.198198    0.493766  1.174457  0.029441    1.144884
# 74   0.197197    0.469048  1.162726  0.027598    1.123635
# 75   0.197197    0.488834  1.162726  0.027598    1.133838
# 76   0.196196    0.479218  1.139853  0.024072    1.112902
# 77   0.196196    0.466667  1.139853  0.024072    1.107357
# 82   0.202202    0.480952  1.141262  0.025028    1.114693
# 83   0.202202    0.479810  1.141262  0.025028    1.114169
# 92   0.200200    0.490196  1.212143  0.035038    1.168284
# 93   0.200200    0.495050  1.212143  0.035038    1.171583
# 114  0.195195    0.479115  1.173128  0.028807    1.135744
# 115  0.195195    0.477941  1.173128  0.028807    1.135107
# 148  0.199199    0.500000  1.186461  0.031306    1.157157
# 149  0.199199    0.472684  1.186461  0.031306    1.140875
# 168  0.196196    0.478049  1.170516  0.028581    1.133423
# 169  0.196196    0.480392  1.170516  0.028581    1.134682
# 176  0.195195    0.476773  1.161697  0.027169    1.126832
# 177  0.195195    0.475610  1.161697  0.027169    1.126243
# 182  0.202202    0.492683  1.169098  0.029246    1.140467
# 183  0.202202    0.479810  1.169098  0.029246    1.133412
# 184  0.199199    0.491358  1.203105  0.033628    1.163081
# 185  0.199199    0.487745  1.203105  0.033628    1.160740
# 208  0.211211    0.520988  1.236263  0.040365    1.207857
# 209  0.211211    0.501188  1.236263  0.040365    1.192021
# 210  0.195195    0.483871  1.205454  0.033269    1.159785
# 211  0.195195    0.486284  1.205454  0.033269    1.161336
# 226  0.196196    0.465558  1.154076  0.026193    1.116299
# 227  0.196196    0.486352  1.154076  0.026193    1.126411
# 238  0.198198    0.470309  1.118663  0.021024    1.094184
# 239  0.198198    0.471429  1.118663  0.021024    1.094608

# %%
def rules_to_coordinates(rules):
    rules['antecedent'] = rules['antecedents'].apply(lambda antecedent:list(antecedent)[0])
    rules['consequent'] = rules['consequents'].apply(lambda consequent:list(consequent)[0])
    rules['rule'] = rules.index
    return rules[['antecedent','consequent','rule']]

# %%
from pandas.plotting import parallel_coordinates
coords = rules_to_coordinates(filtered_rules)
plt.figure(figsize=(3,6))
parallel_coordinates(coords, 'rule',colormap = 'ocean')
plt.legend([])
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_14348/1571138333.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rules['antecedent'] = rules['antecedents'].apply(lambda antecedent:list(antecedent)[0])
# C:\Users\Dell\AppData\Local\Temp/ipykernel_14348/1571138333.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rules['consequent'] = rules['consequents'].apply(lambda consequent:list(consequent)[0])
# C:\Users\Dell\AppData\Local\Temp/ipykernel_14348/1571138333.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rules['rule'] = rules.index

# %%
fig,ax=plt.subplots(4,3) 
count=0 
fig.set_figheight(74) 
fig.set_figwidth(76) 
for rows in range(4): 
    for cols in range(3): 
        sns.countplot(data=df,x=df.columns[count],ax=ax[rows][cols]) 
        count+=1 
        fig.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_14348/1019086969.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\Dell\AppData\Local\Temp/ipykernel_14348/1019086969.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\Dell\AppData\Local\Temp/ipykernel_14348/1019086969.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\Dell\AppData\Local\Temp/ipykernel_14348/1019086969.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\Dell\AppData\Local\Temp/ipykernel_14348/1019086969.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\Dell\AppData\Local\Temp/ipykernel_14348/1019086969.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\Dell\AppData\Local\Temp/ipykernel_14348/1019086969.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\Dell\AppData\Local\Temp/ipykernel_14348/1019086969.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\Dell\AppData\Local\Temp/ipykernel_14348/1019086969.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\Dell\AppData\Local\Temp/ipykernel_14348/1019086969.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\Dell\AppData\Local\Temp/ipykernel_14348/1019086969.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\Dell\AppData\Local\Temp/ipykernel_14348/1019086969.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
